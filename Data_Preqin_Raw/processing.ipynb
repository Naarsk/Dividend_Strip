# %%
import pandas as pd

cashflows = pd.read_excel('Cashflows.xlsx')

# %%
cashflows.describe()
# Out:
#              FUND ID        FIRM ID  VINTAGE / INCEPTION YEAR  \
# count  426028.000000  426028.000000             426028.000000
# mean    35045.270778   30544.065472               2009.460458
# min         3.000000       2.000000               1982.000000
# 25%      6097.000000     479.000000               2005.000000
# 50%     18031.000000    1886.000000               2010.000000
# 75%     53676.000000   12961.000000               2015.000000
# max    226688.000000  727870.000000               2024.000000
# std     38762.888030   83053.007817                  7.464999
#
#        FUND SIZE (USD MN)               TRANSACTION DATE  TRANSACTION AMOUNT  \
# count       410921.000000                         426028        4.260280e+05
# mean          1270.622988  2015-03-25 02:19:55.865060352        2.574059e+06
# min              0.100000            1982-11-09 00:00:00       -1.935000e+07
# 25%            233.000000            2011-02-14 00:00:00       -6.808892e-02
# ...

# %%
funds = pd.read_excel('Funds.xlsx')

# %%
funds.describe()
# Out:
#              FUND ID        FIRM ID  FUND SERIES ID  VINTAGE / INCEPTION YEAR  \
# count  109713.000000  109713.000000    45385.000000             109679.000000
# mean   121126.745718  194099.671033    12328.173119               2016.780350
# min         2.000000       1.000000        4.000000               1969.000000
# 25%     67780.000000   14971.000000     4452.000000               2014.000000
# 50%    128453.000000  151146.000000     9053.000000               2019.000000
# 75%    176801.000000  313210.000000    14571.000000               2022.000000
# max    232316.000000  739103.000000    46534.000000               2026.000000
# std     67440.063405  187862.209740    11402.601950                  7.259228
#
#        FUND SIZE (USD MN)                     DATE ADDED  \
# count        80987.000000                         109713
# mean           305.490814  2019-05-07 20:58:06.161940224
# min              0.000000            2004-05-14 16:47:37
# ...

# %%
print("funds")
print(funds.columns.tolist())
# Out:
# funds
# ...
